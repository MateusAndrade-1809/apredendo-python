# %%
import numpy as np
import sys

# %%
a = [1,2,3,4,5]
b = np.array([1,2,3,4,5])

# %%
print(a)
# Out:
# [1, 2, 3, 4, 5]

# %%
print(b)
# Out:
# [1 2 3 4 5]

# %%
sys.getsizeof(a)
# Out:
# 104

# %%
b.nbytes
# Out:
# 40
