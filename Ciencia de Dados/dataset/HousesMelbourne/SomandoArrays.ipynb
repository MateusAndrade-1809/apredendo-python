# %%
import numpy as np

# %%
a = np.array([2,3,4 ])
b = np.array([2,3,4 ])

# %%
result = a + b
print(result)
# Out:
# [4 6 8]

# %%
c = np.array([[1,2,3,4], [5,6,7,8]])
print(c)
# Out:
# [[1 2 3 4]
#  [5 6 7 8]]

# %%
c[1,2]
# Out:
# np.int64(7)

# %%
c[0,:]
# Out:
# array([1, 2, 3, 4])

# %%
c[:, 1]
# Out:
# array([2, 6])
